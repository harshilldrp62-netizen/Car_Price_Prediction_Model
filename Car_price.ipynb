# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("quikr_car.csv")
df
# Out:
#                                        name    company  year          Price  \
# 0      Hyundai Santro Xing XO eRLX Euro III    Hyundai  2007         80,000
# 1                   Mahindra Jeep CL550 MDI   Mahindra  2006       4,25,000
# 2                Maruti Suzuki Alto 800 Vxi     Maruti  2018  Ask For Price
# 3    Hyundai Grand i10 Magna 1.2 Kappa VTVT    Hyundai  2014       3,25,000
# 4          Ford EcoSport Titanium 1.5L TDCi       Ford  2014       5,75,000
# ..                                      ...        ...   ...            ...
# 887                                      Ta       Tara  zest       3,10,000
# 888                     Tata Zest XM Diesel       Tata  2018       2,60,000
# 889                      Mahindra Quanto C8   Mahindra  2013       3,90,000
# 890                Honda Amaze 1.2 E i VTEC      Honda  2014       1,80,000
# 891               Chevrolet Sail 1.2 LT ABS  Chevrolet  2014       1,60,000
#
#      kms_driven fuel_type
# 0    45,000 kms    Petrol
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 892 entries, 0 to 891
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        892 non-null    object
#  1   company     892 non-null    object
#  2   year        892 non-null    object
#  3   Price       892 non-null    object
#  4   kms_driven  840 non-null    object
#  5   fuel_type   837 non-null    object
# dtypes: object(6)
# memory usage: 41.9+ KB

# %%
df['name'].unique()
# Out:
# array(['Hyundai Santro Xing XO eRLX Euro III', 'Mahindra Jeep CL550 MDI',
#        'Maruti Suzuki Alto 800 Vxi',
#        'Hyundai Grand i10 Magna 1.2 Kappa VTVT',
#        'Ford EcoSport Titanium 1.5L TDCi', 'Ford Figo', 'Hyundai Eon',
#        'Ford EcoSport Ambiente 1.5L TDCi',
#        'Maruti Suzuki Alto K10 VXi AMT', 'Skoda Fabia Classic 1.2 MPI',
#        'Maruti Suzuki Stingray VXi', 'Hyundai Elite i20 Magna 1.2',
#        'Mahindra Scorpio SLE BS IV', 'Audi A8', 'Audi Q7',
#        'Mahindra Scorpio S10', 'Maruti Suzuki Alto 800',
#        'Hyundai i20 Sportz 1.2', 'Maruti Suzuki Alto 800 Lx',
#        'Maruti Suzuki Vitara Brezza ZDi', 'Maruti Suzuki Alto LX',
#        'Mahindra Bolero DI', 'Maruti Suzuki Swift Dzire ZDi',
#        'Mahindra Scorpio S10 4WD', 'Maruti Suzuki Swift Vdi BSIII',
#        'Maruti Suzuki Wagon R VXi BS III',
#        'Maruti Suzuki Wagon R VXi Minor',
#        'Toyota Innova 2.0 G 8 STR BS IV', 'Renault Lodgy 85 PS RXL',
# ...

# %%
# Data Cleaning of Car column

# %%
df[df['name'].str.contains('I want to sell my car Tata Zest')]
# Out:
#                                name company  year          Price kms_driven  \
# 69  I want to sell my car Tata Zest       I  2017  Ask For Price        NaN
# 85  I want to sell my car Tata Zest       I  2017  Ask For Price        NaN
#
#    fuel_type
# 69       NaN
# 85       NaN

# %%
df.drop([69,85],inplace=True)

# %%
df[df['name'].str.contains('selling car Ta')]
# Out:
#                name  company  year          Price kms_driven fuel_type
# 360  selling car Ta  selling  Zest  Ask For Price        NaN       NaN

# %%
df.drop([360],inplace=True)

# %%
df[df['name'].str.contains('URJE')]
# Out:
#      name company  year     Price kms_driven fuel_type
# 401  URJE  URJENT  SELL  1,80,000        NaN       NaN

# %%
df.drop([401],inplace=True)

# %%
df[df['name'].str.contains('Used Commercial Maruti Omn')]
# Out:
#                            name company  year     Price kms_driven fuel_type
# 441  Used Commercial Maruti Omn    Used  arry  1,50,000        NaN       NaN

# %%
df.drop([441],inplace=True)

# %%
df[df['name'].str.contains('Sale tata')]
# Out:
#           name company  year     Price kms_driven fuel_type
# 616  Sale tata    Sale  ture  1,00,000        NaN       NaN

# %%
df.drop([616],inplace=True)

# %%
df[df['name'].str.contains('very good condition tata bolts are av')]
# Out:
#                                       name company  year     Price kms_driven  \
# 643  very good condition tata bolts are av    very  able  2,00,000        NaN
#
#     fuel_type
# 643       NaN

# %%
df.drop([643],inplace=True)

# %%
df[df['name'].str.contains('')]
# Out:
#                                        name    company  year          Price  \
# 0      Hyundai Santro Xing XO eRLX Euro III    Hyundai  2007         80,000
# 1                   Mahindra Jeep CL550 MDI   Mahindra  2006       4,25,000
# 2                Maruti Suzuki Alto 800 Vxi     Maruti  2018  Ask For Price
# 3    Hyundai Grand i10 Magna 1.2 Kappa VTVT    Hyundai  2014       3,25,000
# 4          Ford EcoSport Titanium 1.5L TDCi       Ford  2014       5,75,000
# ..                                      ...        ...   ...            ...
# 887                                      Ta       Tara  zest       3,10,000
# 888                     Tata Zest XM Diesel       Tata  2018       2,60,000
# 889                      Mahindra Quanto C8   Mahindra  2013       3,90,000
# 890                Honda Amaze 1.2 E i VTEC      Honda  2014       1,80,000
# 891               Chevrolet Sail 1.2 LT ABS  Chevrolet  2014       1,60,000
#
#      kms_driven fuel_type
# 0    45,000 kms    Petrol
# ...

# %%
df['year'].unique()
# Out:
# array(['2007', '2006', '2018', '2014', '2015', '2012', '2013', '2016',
#        '2010', '2017', '2008', '2011', '2019', '2009', '2005', '2000',
#        '...', '150k', 'TOUR', '2003', 'r 15', '2004', '/-Rs', 'sale',
#        '1995', 'ara)', '2002', '2001', 'tion', 'odel', '2 bs', 'Eon',
#        'o...', 'Zest', 'emi', 'car', 'no.', 'd...', 'SALE', 'digo',
#        'sell', 'd Ex', 'n...', 'e...', 'D...', ', Ac', 'go .', 'k...',
#        'o c4', 'zire', 'cent', 'Sumo', 'cab', 't xe', 'EV2', 'r...',
#        'zest'], dtype=object)

# %%
df = df[df['year'].str.isdigit()]

# %%
df['year'].unique()
# Out:
# array(['2007', '2006', '2018', '2014', '2015', '2012', '2013', '2016',
#        '2010', '2017', '2008', '2011', '2019', '2009', '2005', '2000',
#        '2003', '2004', '1995', '2002', '2001'], dtype=object)

# %%
df['year'] = pd.to_datetime(df['year'], format='%Y').dt.to_period('Y')
# Out:
# C:\Users\hp410\AppData\Local\Temp\ipykernel_13840\3041659430.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['year'] = pd.to_datetime(df['year'], format='%Y').dt.to_period('Y')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 840 entries, 0 to 891
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        840 non-null    object
#  1   company     840 non-null    object
#  2   year        840 non-null    period[Y-DEC]
#  3   Price       840 non-null    object
#  4   kms_driven  840 non-null    object
#  5   fuel_type   837 non-null    object
# dtypes: object(5), period[Y-DEC](1)
# memory usage: 45.9+ KB

# %%
df['Price'] = df['Price'].str.replace(',','')
# Out:
# C:\Users\hp410\AppData\Local\Temp\ipykernel_13840\986327726.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Price'] = df['Price'].str.replace(',','')

# %%
df = df[df['Price'].str.isdigit()]

# %%
df['fuel_type'] = df['fuel_type'].fillna('Petrol')

# %%
df['kms_driven'].head()
# Out:
# 0    45,000 kms
# 1        40 kms
# 3    28,000 kms
# 4    36,000 kms
# 6    41,000 kms
# Name: kms_driven, dtype: object

# %%
df['kms_driven'] = df['kms_driven'].str.replace(' kms','')
df['kms_driven'] = df['kms_driven'].str.replace(',','')

# %%
df['kms_driven'].head()
# Out:
# 0    45000
# 1       40
# 3    28000
# 4    36000
# 6    41000
# Name: kms_driven, dtype: object

# %%
df[df['kms_driven'].str.isdigit()]
# Out:
#                                        name   company  year   Price  \
# 0      Hyundai Santro Xing XO eRLX Euro III   Hyundai  2007   80000
# 1                   Mahindra Jeep CL550 MDI  Mahindra  2006  425000
# 3    Hyundai Grand i10 Magna 1.2 Kappa VTVT   Hyundai  2014  325000
# 4          Ford EcoSport Titanium 1.5L TDCi      Ford  2014  575000
# 6                                 Ford Figo      Ford  2012  175000
# ..                                      ...       ...   ...     ...
# 883              Maruti Suzuki Ritz VXI ABS    Maruti  2011  270000
# 885               Tata Indica V2 DLE BS III      Tata  2009  110000
# 886                    Toyota Corolla Altis    Toyota  2009  300000
# 888                     Tata Zest XM Diesel      Tata  2018  260000
# 889                      Mahindra Quanto C8  Mahindra  2013  390000
#
#     kms_driven fuel_type
# 0        45000    Petrol
# 1           40    Diesel
# 3        28000    Petrol
# 4        36000    Diesel
# ...

# %%
df.loc[[890,891],'kms_driven'] = 500

# %%
df['kms_driven'] = df['kms_driven'].astype('int64')

# %%
df['Price'] = df['Price'].astype('int64')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 819 entries, 0 to 891
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        819 non-null    object
#  1   company     819 non-null    object
#  2   year        819 non-null    period[Y-DEC]
#  3   Price       819 non-null    int64
#  4   kms_driven  819 non-null    int64
#  5   fuel_type   819 non-null    object
# dtypes: int64(2), object(3), period[Y-DEC](1)
# memory usage: 77.1+ KB

# %%
# Data Cleaning Completed !!

# %%
df = df.reset_index(drop=True)

# %%
#df.to_csv('cleaned_carprice.csv', index=False)

# %%
df1 = pd.read_csv('cleaned_carprice.csv')

# %%
x = df1.drop(columns='Price')
y = df1['Price']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import make_column_transformer
from sklearn.pipeline import make_pipeline

# %%
ohe = OneHotEncoder(handle_unknown='ignore')
ohe.fit(x[['name','company','fuel_type']])
# Out:
# OneHotEncoder(handle_unknown='ignore')

# %%
column_trans = make_column_transformer((OneHotEncoder(categories=ohe.categories_),['name','company','fuel_type']),remainder = 'passthrough')

# %%
lr = LinearRegression()

# %%
pipe = make_pipeline(column_trans,lr)

# %%
pipe.fit(x_train,y_train)
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(categories=[array(['Audi A3 Cabriolet 40 TFSI',
#        'Audi A4 1.8 TFSI Multitronic Premium Plus',
#        'Audi A4 2.0 TDI 177bhp Premium', 'Audi A6 2.0 TDI Premium',
#        'Audi A8', 'Audi Q3 2.0 TDI quattro Premium',
#        'Audi Q5 2.0 TDI quattro Premium Plus', 'Audi Q7',
#        'BMW 3 Series 320d...
#                                                                             array(['Audi', 'BMW', 'Chevrolet', 'Datsun', 'Fiat', 'Force', 'Ford',
#        'Hindustan', 'Honda', 'Hyundai', 'Jaguar', 'Jeep', 'Land',
#        'Mahindra', 'Maruti', 'Mercedes', 'Mini', 'Mitsubishi', 'Nissan',
#        'Renault', 'Skoda', 'Tata', 'Toyota', 'Volkswagen', 'Volvo'],
#       dtype=object),
# ...

# %%
y_pred = pipe.predict(x_test)

# %%
r2_score(y_test,y_pred)
# Out:
# 0.012708683203946691

# %%
scores = []
for i in range(1000):
    x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=i)
    lr = LinearRegression()    
    pipe = make_pipeline(column_trans,lr)
    pipe.fit(x_train,y_train)
    y_pred = pipe.predict(x_test)
    scores.append(r2_score(y_test,y_pred))

# %%
np.argmax(scores)
# Out:
# np.int64(989)

# %%
scores[np.argmax(scores)]
# Out:
# 0.7919643425892495

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=np.argmax(scores))
lr = LinearRegression()    
pipe = make_pipeline(column_trans,lr)
pipe.fit(x_train,y_train)
y_pred = pipe.predict(x_test)
r2_score(y_test,y_pred)
# Out:
# 0.7919643425892495

# %%
import pickle

# %%
pickle.dump(pipe,open('CarPriceModel.pkl','wb'))

# %%
pipe.predict(pd.DataFrame([['Hyundai Grand i10 Magna 1.2 Kappa VTVT','Hyundai',2020,10000,'Petrol']],columns=['name','company','year','kms_driven','fuel_type']))
# Out:
# array([574192.14199291])

# %%
df1.head()
# Out:
#                                      name   company  year   Price  kms_driven  \
# 0    Hyundai Santro Xing XO eRLX Euro III   Hyundai  2007   80000       45000
# 1                 Mahindra Jeep CL550 MDI  Mahindra  2006  425000          40
# 2  Hyundai Grand i10 Magna 1.2 Kappa VTVT   Hyundai  2014  325000       28000
# 3        Ford EcoSport Titanium 1.5L TDCi      Ford  2014  575000       36000
# 4                               Ford Figo      Ford  2012  175000       41000
#
#   fuel_type
# 0    Petrol
# 1    Diesel
# 2    Petrol
# 3    Diesel
# 4    Diesel

# %%
import joblib

# %%
from sklearn.pipeline import Pipeline
# Wrap everything in a pipeline
model_pipeline = Pipeline([
    ('encoder', ohe),
    ('regressor', lr)
])
joblib.dump(model_pipeline, 'CarPricePipeline.joblib')
# Out:
# ['CarPricePipeline.joblib']

# %%
# In your training script (where you defined the pipeline)
print(model_pipeline.feature_names_in_)
# Out:
# ['name' 'company' 'fuel_type']

# %%
df.sample(5)
# Out:
#                                 name  company  year    Price  kms_driven  \
# 257              Maruti Suzuki Dzire   Maruti  2009   220000       46000
# 695             Hyundai Creta 1.6 SX  Hyundai  2019  1200000           0
# 388     Hyundai Elite i20 Sportz 1.2  Hyundai  2018   600000        7800
# 242      Maruti Suzuki Ciaz ZXI Plus   Maruti  2017   699000       14000
# 425  Audi Q3 2.0 TDI quattro Premium     Audi  2013  1499000       37000
#
#     fuel_type
# 257    Petrol
# 695    Petrol
# 388    Petrol
# 242    Petrol
# 425    Diesel

# %%
from sklearn.metrics import mean_squared_error,root_mean_squared_error,mean_absolute_error

# %%
root_mean_squared_error(y_pred,y_test)
# Out:
# 184929.97396848034

# %%
plt.scatter(y_pred,y_test)
